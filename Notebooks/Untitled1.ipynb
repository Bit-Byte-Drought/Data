# %% [markdown]
# # Rainfall

# %%
import pandas as pd
import numpy as np
df = pd.read_excel(
    '../Datasets/rainfall_District Wise Timeseries_1594880916242.xls',          #Relative path
    header = [1,2]                        #Selecting rows for column name
).replace('-', np.nan)                    #Replacing - with Nan

# %%
df.head()
# Out:
#                STATE                DISTRICT 01 Jan 2013              \
#   Unnamed: 0_level_1      Unnamed: 1_level_1 Actual (mm) Normal (mm)
# 0  ANDAMAN & NICOBAR                 NICOBAR         NaN         2.7
# 1  ANDAMAN & NICOBAR           SOUTH ANDAMAN         NaN         NaN
# 2  ANDAMAN & NICOBAR  NORTH & MIDDLE ANDAMAN         NaN         3.2
# 3          RAJASTHAN              GANGANAGAR         NaN         0.3
# 4          RAJASTHAN                   ALWAR         NaN         0.3
#
#                  02 Jan 2013                            03 Jan 2013  \
#   Deviation (mm) Actual (mm) Normal (mm) Deviation (mm) Actual (mm)
# 0            NaN         NaN         3.1            NaN         NaN
# 1            NaN         NaN         NaN            NaN         NaN
# 2            NaN         NaN         3.5            NaN         NaN
# 3            NaN         NaN         0.3            NaN         NaN
# 4            NaN         NaN         0.2            NaN         NaN
#
#                ...    28 Dec 2013 29 Dec 2013                             \
#   Normal (mm)  ... Deviation (mm) Actual (mm) Normal (mm) Deviation (mm)
# 0         0.5  ...            NaN         NaN         3.0            NaN
# 1         NaN  ...            NaN         NaN         NaN            NaN
# 2         3.5  ...            NaN         NaN         5.1            NaN
# 3         0.2  ...            NaN         NaN         0.2            NaN
# 4         0.0  ...            NaN         NaN         0.0            NaN
#
#   30 Dec 2013                            31 Dec 2013              \
#   Actual (mm) Normal (mm) Deviation (mm) Actual (mm) Normal (mm)
# 0         NaN         4.4            NaN         NaN         7.2
# 1         NaN         NaN            NaN         NaN         NaN
# 2         NaN         6.1            NaN         NaN         7.1
# 3         NaN         0.2            NaN         NaN         0.0
# 4         NaN         0.2            NaN         NaN         0.0
#
#
#   Deviation (mm)
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 1097 columns]

# %% [markdown]
# As we can see above, It looks like there are columns and rows consisting only of NaN values.

# %%
df.shape
# Out:
# (630, 1097)

# %% [markdown]
# We have 630 instances and 1097 attributes.

# %%
Actual = df[df.columns[2::3]].apply(lambda x:x.isna().sum())

# %%
Actual.head()
# Out:
# 01 Jan 2013  Actual (mm)    630
# 02 Jan 2013  Actual (mm)    630
# 03 Jan 2013  Actual (mm)    630
# 04 Jan 2013  Actual (mm)    630
# 05 Jan 2013  Actual (mm)    630
# dtype: int64

# %%
Actual.value_counts()
# Out:
# 630    365
# dtype: int64

# %% [markdown]
# As we can see above, all the attributes corresponding to `Actual` are only NaNs.

# %%
Deviation = df[df.columns[4::3]].apply(lambda x:x.isna().sum())

# %%
Deviation.head()
# Out:
# 01 Jan 2013  Deviation (mm)    630
# 02 Jan 2013  Deviation (mm)    630
# 03 Jan 2013  Deviation (mm)    630
# 04 Jan 2013  Deviation (mm)    630
# 05 Jan 2013  Deviation (mm)    630
# dtype: int64

# %%
Deviation.value_counts()
# Out:
# 630    365
# dtype: int64

# %% [markdown]
# As we can see above, all the attributes corresponding to `Deviation` are only NaNs.

# %%
index = df[df.columns[0:2]]
index.columns = ['State', 'District']
df = df[df.columns[3::3]]
df.index = pd.MultiIndex.from_frame(index)
df.columns = pd.Series(df.columns.to_numpy()).apply(lambda x:x[0])
df.head()
# Out:
#                                           01 Jan 2013  02 Jan 2013  \
# State             District
# ANDAMAN & NICOBAR NICOBAR                         2.7          3.1
#                   SOUTH ANDAMAN                   NaN          NaN
#                   NORTH & MIDDLE ANDAMAN          3.2          3.5
# RAJASTHAN         GANGANAGAR                      0.3          0.3
#                   ALWAR                           0.3          0.2
#
#                                           03 Jan 2013  04 Jan 2013  \
# State             District
# ANDAMAN & NICOBAR NICOBAR                         0.5          1.0
#                   SOUTH ANDAMAN                   NaN          NaN
#                   NORTH & MIDDLE ANDAMAN          3.5          4.8
# RAJASTHAN         GANGANAGAR                      0.2          0.2
#                   ALWAR                           0.0          0.2
#
#                                           05 Jan 2013  06 Jan 2013  \
# State             District
# ANDAMAN & NICOBAR NICOBAR                         0.5          1.8
#                   SOUTH ANDAMAN                   NaN          NaN
#                   NORTH & MIDDLE ANDAMAN          4.4          6.1
# RAJASTHAN         GANGANAGAR                      0.2          0.3
#                   ALWAR                           0.8          0.0
#
#                                           07 Jan 2013  08 Jan 2013  \
# State             District
# ANDAMAN & NICOBAR NICOBAR                         2.6          3.9
#                   SOUTH ANDAMAN                   NaN          NaN
#                   NORTH & MIDDLE ANDAMAN          7.0          8.2
# RAJASTHAN         GANGANAGAR                      0.3          0.3
#                   ALWAR                           0.5          0.2
#
#                                           09 Jan 2013  10 Jan 2013  ...  \
# State             District                                          ...
# ANDAMAN & NICOBAR NICOBAR                         5.5          3.2  ...
#                   SOUTH ANDAMAN                   NaN          NaN  ...
#                   NORTH & MIDDLE ANDAMAN          5.5          5.4  ...
# RAJASTHAN         GANGANAGAR                      0.4          0.0  ...
#                   ALWAR                           0.6          0.4  ...
#
#                                           22 Dec 2013  23 Dec 2013  \
# State             District
# ANDAMAN & NICOBAR NICOBAR                         0.7          3.4
#                   SOUTH ANDAMAN                   NaN          NaN
#                   NORTH & MIDDLE ANDAMAN          7.7          6.2
# RAJASTHAN         GANGANAGAR                      0.0          0.1
#                   ALWAR                           0.1          0.6
#
#                                           24 Dec 2013  25 Dec 2013  \
# State             District
# ANDAMAN & NICOBAR NICOBAR                         6.0          3.2
#                   SOUTH ANDAMAN                   NaN          NaN
#                   NORTH & MIDDLE ANDAMAN          6.7          7.0
# RAJASTHAN         GANGANAGAR                      0.0          0.1
#                   ALWAR                           0.2          0.1
#
#                                           26 Dec 2013  27 Dec 2013  \
# State             District
# ANDAMAN & NICOBAR NICOBAR                         3.2          1.4
#                   SOUTH ANDAMAN                   NaN          NaN
#                   NORTH & MIDDLE ANDAMAN          5.7          6.8
# RAJASTHAN         GANGANAGAR                      0.4          0.4
#                   ALWAR                           0.1          0.3
#
#                                           28 Dec 2013  29 Dec 2013  \
# State             District
# ANDAMAN & NICOBAR NICOBAR                         0.5          3.0
#                   SOUTH ANDAMAN                   NaN          NaN
#                   NORTH & MIDDLE ANDAMAN          5.0          5.1
# RAJASTHAN         GANGANAGAR                      0.1          0.2
#                   ALWAR                           0.1          0.0
#
#                                           30 Dec 2013  31 Dec 2013
# State             District
# ANDAMAN & NICOBAR NICOBAR                         4.4          7.2
#                   SOUTH ANDAMAN                   NaN          NaN
#                   NORTH & MIDDLE ANDAMAN          6.1          7.1
# RAJASTHAN         GANGANAGAR                      0.2          0.0
#                   ALWAR                           0.2          0.0
#
# [5 rows x 365 columns]

# %% [markdown]
# Separating first two columns to a variable `index`.<br>
# Renaming the columns from `index` in the second line.<br>
# Considering only Normal attribute from all our days and saving it to `df`.<br>
# Adding a MultiIndex to our df through `index`.<br>
# Dropping the Recurring attribute name 'Normal(mm)'.

# %%
df.to_csv('../Datasets/Normal Rainfall(2013)')

# %%
df.apply(lambda x:print(x.name) if x.isna().sum() == 365 else None,axis = 1).value_counts()
# Out:
# ('ANDAMAN & NICOBAR', 'SOUTH ANDAMAN')
# ('NAGALAND', 'DIMAPUR')
# ('NAGALAND', 'MOKOKCHUNG')
# ('NAGALAND', 'LONGLENG')
# ('NAGALAND', 'WOKHA')
# ('NAGALAND', 'ZUNHEBOTO')
# ('NAGALAND', 'KIPHIRE')
# ('NAGALAND', 'PEREN')
# ('UTTARAKHAND', 'BAGESHWAR')
# ('DADRA AND NAGAR HAV', 'DADRA & NAGAR HAVELI')
# ('MADHYA PRADESH', 'ALIRAJPUR')
# ('MADHYA PRADESH', 'EAST NIMAR')
# ('MADHYA PRADESH', 'SINGRAULI')
# ('MADHYA PRADESH', 'ASHOKNAGAR')
# ('MADHYA PRADESH', 'ANUPPUR')
# ('MADHYA PRADESH', 'BURHANPUR')
# ('SIKKIM', 'EAST')
# ('SIKKIM', 'NORTH')
# ('SIKKIM', 'SOUTH')
# ('MEGHALAYA', 'WEST KHASI HILLS')
# ('MEGHALAYA', 'RI BHOI')
# ('MEGHALAYA', 'WEST GARO HILLS')
# ('MEGHALAYA', 'EAST KHASI HILLS')
# ('MEGHALAYA', 'SOUTH GARO HILLS')
# ('PONDICHERRY', 'MAHE')
# ('PONDICHERRY', 'KARAIKAL')
# ('PONDICHERRY', 'YANAM')
# ('CHHATTISGARH', 'NARAYANPUR')
# ('BIHAR', 'SHEOHAR')
# ('BIHAR', 'BANKA')
# ('BIHAR', 'LAKHISARAI')
# ('BIHAR', 'VAISHALI')
# ('BIHAR', 'JEHANABAD')
# ('BIHAR', 'JAMUI')
# ('BIHAR', 'SHEIKHPURA')
# ('BIHAR', 'NAWADA')
# ('BIHAR', 'ARWAL')
# ('BIHAR', 'ARARIA')
# ('WEST BENGAL', 'KOLKATA')
# ('WEST BENGAL', 'PURBA MEDINIPUR')
# ('ODISHA', 'KANDHAMAL')
# ('ODISHA', 'KENDRAPARA')
# ('ODISHA', 'NABARANGAPUR')
# ('GUJARAT', 'TAPI')
# ('GOA', 'NORTH GOA')
# ('Ladakh', 'KARGIL')
# ('Ladakh', 'Ladakh dist1')
# ('Ladakh', 'Leh (ladakh)')
# ('UTTAR PRADESH', 'CHANDAULI')
# ('UTTAR PRADESH', 'MAHOBA')
# ('UTTAR PRADESH', 'CHITRAKOOT')
# ('UTTAR PRADESH', 'SANT KABIR NAGAR')
# ('UTTAR PRADESH', 'KANNAUJ')
# ('UTTAR PRADESH', 'KAUSHAMBI')
# ('UTTAR PRADESH', 'PRATAPGARH')
# ('UTTAR PRADESH', 'GAUTAM BUDDHA NAGAR')
# ('UTTAR PRADESH', 'KANSIRAM NAGAR')
# ('TRIPURA', 'DHALAI')
# ('LAKSHDWEEP', 'LAKSHADWEEP')
# ('TAMILNADU', 'TIRUPPUR')
# ('TAMILNADU', 'ARIYALUR')
# ('TAMILNADU', 'KRISHNAGIRI')
# ('MANIPUR', 'CHANDEL')
# ('MANIPUR', 'TAMENGLONG')
# ('MANIPUR', 'IMPHAL EAST')
# ('MANIPUR', 'THOUBAL')
# ('MANIPUR', 'UKHRUL')
# ('MANIPUR', 'BISHNUPUR')
# ('MIZORAM', 'SAIHA')
# ('MIZORAM', 'LUNGLEI')
# ('MIZORAM', 'MAMIT')
# ('MIZORAM', 'LAWANGTLAI')
# ('MIZORAM', 'SERCHHIP')
# ('MIZORAM', 'KOLASIB')
# ('JHARKHAND', 'JAMTARA')
# ('JHARKHAND', 'GARHWA')
# ('JHARKHAND', 'RAMGARH')
# ('JHARKHAND', 'CHATRA')
# ('JHARKHAND', 'LOHARDAGA')
# ('JHARKHAND', 'GODDA')
# ('JHARKHAND', 'DEOGHAR')
# ('JHARKHAND', 'LATEHAR')
# ('JHARKHAND', 'SARAIKELA-KHARSAWAN')
# ('JHARKHAND', 'SIMDEGA')
# ('JHARKHAND', 'KHUNTI')
# ('MAHARASHTRA', 'MUMBAI SUBURBAN')
# ('MAHARASHTRA', 'HINGOLI')
# ('HARYANA', 'PALWAL')
# ('HARYANA', 'MEWAT')
# ('ARUNACHAL PRADESH', 'KURUNG KUMEY')
# ('ARUNACHAL PRADESH', 'LOWER DIBANG VALLEY')
# ('ARUNACHAL PRADESH', 'ANJAW')
# ('DELHI', 'WEST')
# ('DELHI', 'NORTH WEST')
# ('DELHI', 'SOUTH')
# ('DELHI', 'NEW DELHI')
# ('DELHI', 'NORTH')
# ('DELHI', 'EAST')
# ('DELHI', 'SOUTH WEST')
# ('DELHI', 'NORTH EAST')
# ('PUNJAB', 'MANSA')
# ('PUNJAB', 'SAHIBZADA AJIT SINGH NAGAR')
# ('PUNJAB', 'TARN TARAN')
# ('PUNJAB', 'BARNALA')
# ('ASSAM', 'KAMRUP METROPOLITAN')
# ('ASSAM', 'CHIRANG')
# ('ASSAM', 'UDALGURI')
# ('ASSAM', 'DHEMAJI')
# ('ASSAM', 'BAKSA')
# ('DAMAN & DIU', 'DAMAN')
# ('JAMMU & KASHMIR', 'SAMBA')
# ('JAMMU & KASHMIR', 'RAJOURI')
# ('JAMMU & KASHMIR', 'J&K District 1')
# ('KARNATAKA', 'BIJAPUR')
# ('KARNATAKA', 'CHIKKABALLAPURA')
# ('KARNATAKA', 'RAMANAGARA')
# ('KARNATAKA', 'YADGIR')
# Series([], dtype: int64)
